# %%
import random

## the brains of the game
def game():
    
    possible_moves = ['rock', 'paper', 'scissors']
    Player_move = input('Your move: Rock, Paper, or Scissors?: ').lower()
    
    while True:
        try:
            if Player_move not in possible_moves:
                raise ValueError
            break
        except ValueError:
            print("Sorry you did not follow the rules and enter Rock Paper or Scissors, I win by default, better luck next time")
            break
    

    for i in player_choices:
        if i == 'rock':
            rock = choice_breakdown['rock']
        else:
            rock = 0
    
    for i in player_choices:
        if i == 'paper':
            paper = choice_breakdown['paper']
        else:
            paper = 0
            
    for i in player_choices:
        if i == 'scissors':
            scissors = choice_breakdown['scissors']
        else:
            scissors = 0

## Stratagy if you have chosen 1 more than 50% of the time will perdict to do so again     
    if rock >= (paper + scissors):
        My_Move = 'paper'
    elif paper >= (rock + scissors):
        My_Move = 'scissors'
    elif scissors >= (paper + rock):
        My_Move = 'rock'
## if you have a bias towards 2 of the options then you will chose the one that will win or tie
    elif rock + paper > 3*scissors:
        My_Move = 'paper'
    elif paper + scissors > 3*rock:
        My_Move = 'scissors'
    elif rock + scissors > 3*paper:
        My_Move = 'rock'
    else:
        My_Move = random.choice(possible_moves)
## Determine winner                                                                                                             
    if Player_move in possible_moves:
        print('You chose',Player_move,', I chose', My_Move)
    
    if Player_move not in possible_moves:
        print(":(")
    elif My_Move == Player_move:
        print("We both chose", Player_move, "Tie!")
    
    elif My_Move == "rock":
        if Player_move == 'paper':
            print ("Paper covers rock, which really doesn't do much but I guess You Win :(")
        else:
            print ("Rock crushes Scissors!! You Lose ! I cannot be beat!!")

    elif My_Move == "paper":
        if Player_move == 'scissors':
            print ("Scissors cut paper! You Win :(")
        else:
            print ("Paper gently covers rock!! No no one can see you! you lose!")

    elif My_Move == "scissors":
        if Player_move == 'rock':
            print ("Rock crushes Scissors! gee dang, i'll get you next time")
        else:
            print ("Scissors cut Paper and I turn you in to a snowflake Mwhaha!!")
## adding a record of player choice so it can change stratagy
    player_choices.append(Player_move)
## deleting the first line so you can move form their previous bias
    player_choices.pop(0)

play_again = 'yes'
## Starting with  of each so there is not an imediate bias to any
player_choices = ['rock','paper','scissors','rock','paper','scissors','rock','paper','scissors']
choice_breakdown = dict((i, player_choices.count(i))for i in player_choices)


## loop to make it play
while play_again == 'yes':
    game()
    play_again = input("Would you like to play again? Yes or No: ").lower()
    choice_breakdown = dict((i, player_choices.count(i))for i in player_choices)   



print(player_choices)
print(choice_breakdown)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6dd3ffa91dd5> in <module>
#      90 ## loop to make it play
#      91 while play_again == 'yes':
# ---> 92     game()
#      93     play_again = input("Would you like to play again? Yes or No: ").lower()
#      94     choice_breakdown = dict((i, player_choices.count(i))for i in player_choices)
#
# <ipython-input-3-6dd3ffa91dd5> in game()
#       5
#       6     possible_moves = ['rock', 'paper', 'scissors']
# ----> 7     Player_move = input('Your move: Rock, Paper, or Scissors?: ').lower()
#       8
#       9     while True:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def game():
    
    play_again = 'yes'
    ## Starting with  of each so there is not an imediate bias to any
    player_choices = ['rock','paper','scissors','rock','paper','scissors','rock','paper','scissors']
    choice_breakdown = dict((i, player_choices.count(i))for i in player_choices)
    possible_moves = ['rock', 'paper', 'scissors']

    ## loop to make it play
    while play_again == 'yes':
    
        Player_move = input('Your move: Rock, Paper, or Scissors?: ').lower()

        while True:
            try:
                if Player_move not in possible_moves:
                    raise ValueError
                break
            except ValueError:
                print("Sorry you did not follow the rules and enter Rock Paper or Scissors, I win by default, better luck next time")
                break


        for i in player_choices:
            if i == 'rock':
                rock = choice_breakdown['rock']
            else:
                rock = 0

        for i in player_choices:
            if i == 'paper':
                paper = choice_breakdown['paper']
            else:
                paper = 0

        for i in player_choices:
            if i == 'scissors':
                scissors = choice_breakdown['scissors']
            else:
                scissors = 0

    ## Stratagy if you have chosen 1 more than 50% of the time will perdict to do so again     
        if rock >= (paper + scissors):
            My_Move = 'paper'
        elif paper >= (rock + scissors):
            My_Move = 'scissors'
        elif scissors >= (paper + rock):
            My_Move = 'rock'
    ## if you have a bias towards 2 of the options then you will chose the one that will win or tie
        elif rock + paper > 3*scissors:
            My_Move = 'paper'
        elif paper + scissors > 3*rock:
            My_Move = 'scissors'
        elif rock + scissors > 3*paper:
            My_Move = 'rock'
        else:
            My_Move = random.choice(possible_moves)
    
    ## Determine winner                                                                                                             
        if Player_move in possible_moves:
            print('You chose',Player_move,', I chose', My_Move)

        if Player_move not in possible_moves:
            print(":(")
        elif My_Move == Player_move:
            print("We both chose", Player_move, "Tie!")

        elif My_Move == "rock":
            if Player_move == 'paper':
                print ("Paper covers rock, which really doesn't do much but I guess You Win :(")
            else:
                print ("Rock crushes Scissors!! You Lose ! I cannot be beat!!")

        elif My_Move == "paper":
            if Player_move == 'scissors':
                print ("Scissors cut paper! You Win :(")
            else:
                print ("Paper gently covers rock!! No no one can see you! you lose!")

        elif My_Move == "scissors":
            if Player_move == 'rock':
                print ("Rock crushes Scissors! gee dang, i'll get you next time")
            else:
                print ("Scissors cut Paper and I turn you in to a snowflake Mwhaha!!")
    ## adding a record of player choice so it can change stratagy
        player_choices.append(Player_move)
    ## deleting the first line so you can move form their previous bias
        player_choices.pop(0)
        
        play_again = input("Would you like to play again? Yes or No: ").lower()
        choice_breakdown = dict((i, player_choices.count(i))for i in player_choices) 
        

    
game()
# Out:
# Your move: Rock, Paper, or Scissors?: paper
# You chose paper , I chose rock
# Paper covers rock, which really doesn't do much but I guess You Win :(
# Would you like to play again? Yes or No: yes
# Your move: Rock, Paper, or Scissors?: rock
# You chose rock , I chose scissors
# Rock crushes Scissors! gee dang, i'll get you next time
# Would you like to play again? Yes or No: no

# %%
print(rock)
print(paper)
print(scissors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ed3d5115fbb2> in <module>
# ----> 1 print(rock)
#       2 print(paper)
#       3 print(scissors)
#
# NameError: name 'rock' is not defined

# %%
if choice_breakdown['paper'] >= 1:
        paper = choice_breakdown['paper']
    else:
        paper = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-195c233afea0> in <module>
# ----> 1 help(lstrip)
#
# NameError: name 'lstrip' is not defined
